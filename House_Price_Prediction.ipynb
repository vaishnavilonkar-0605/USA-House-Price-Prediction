# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\DELL\Desktop\ML\LR\USA_Housing.csv")
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
df.head(3)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
#
#    Avg. Area Number of Bedrooms  Area Population        Price
# 0                          4.09      23086.80050  1059033.558
# 1                          3.09      40173.07217  1505890.915
# 2                          5.13      36882.15940  1058987.988

# %%
df.tail(3)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population        Price
# 4997                          2.13      33266.14549  1030729.583
# 4998                          5.44      42625.62016  1198656.872
# 4999                          4.07      46501.28380  1298950.480

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
import Omkar_statistics

for col_name in df.columns:
    Omkar_statistics.cal_stats(col_name, df[col_name])
    print('-' * 50)
# Out:
# Avg. Area Income
# Total Sum 342915544.91985
# Total Count 5000
# Minimum 17796.63119
# Maximum 107701.7484
# Range 89905.12
# Average 68583.11
# Median 68804.29
# Mode ModeResult(mode=np.float64(17796.63119), count=np.int64(1))
# Q1 61480.56239
# Q3 75783.33866499999
# IQR 14302.77627499999
# Lower Whisker 40026.39797750002
# Upper Whisker 97237.50307749998
# Variance 113570058.1599854
# Standard Deviation 10656.925361472013
# Skewness -0.03370985850476661
# Kurtosis 0.044328500390600656
# --------------------------------------------------
# Avg. Area House Age
# Total Sum 29886.110176435002
# Total Count 5000
# Minimum 2.644304186
# Maximum 9.519088066
# Range 6.87
# Average 5.98
# Median 5.97
# Mode ModeResult(mode=np.float64(2.644304186), count=np.int64(1))
# Q1 5.32228301575
# Q3 6.65080847925
# IQR 1.3285254635000001
# Lower Whisker 3.3294948205
# Upper Whisker 8.6435966745
# Variance 0.9827887594565956
# Standard Deviation 0.9913570292566627
# Skewness -0.007211708026019969
# ...

# %%
for col_name in df.columns:
    print(col_name)
    sns.displot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
for col_name in df.columns:
    print(col_name)
    sns.kdeplot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
for col_name in df.columns:
    print(col_name)
    sns.violinplot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Price',axis=1)
y = df['Price']

X_train , X_test , y_train , y_test = train_test_split(X,y , test_size = 0.2)

# %%
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
# Out:
# X_train shape: (4000, 5)
# X_test shape: (1000, 5)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print ('Slopes :', lr.coef_)
print ('Intercept: ', lr.intercept_)
# Out:
# Slopes : [2.16932190e+01 1.65495181e+05 1.20360075e+05 1.25860655e+03
#  1.51297646e+01]
# Intercept:  -2636750.5928634983

# %%
y_pred = lr.predict(X_test)

# %%
print('First 5 predictions:', y_pred[:5])
print('First 5 actual:', y_test[:5].values)
# Out:
# First 5 predictions: [1285338.23996249 1699714.08710082  790173.24658087 1224931.40182485
#  1562108.00736683]
# First 5 actual: [1446155.18   1558196.969   803259.6126 1186357.179  1439431.453 ]

# %%
# Sum of Squared Error
sse = sum((y_pred - y_test)**2)
print('Sum of Squared Error', sse)

# Mean Squared Error
mse = sum((y_pred - y_test)**2) / 1000
print('Mean Squared Error', mse)

# Root Mean Squared Error
rmse = np.sqrt(sum((y_pred - y_test)**2) / 1000)
print('Root Mean Squared Error', rmse)
# Out:
# Sum of Squared Error 10026558567089.514
# Mean Squared Error 10026558567.089514
# Root Mean Squared Error 100132.70478265088

# %%
df['Price'].mean()
# Out:
# np.float64(1232072.6541453)

# %%
sns.displot(y_pred - y_test)
plt.show()

# %%
print('Welcome to USA House Price Prediction')

income = float(input('Please enter income here: '))
house_age = float(input('Please enter house age here: '))
no_of_rooms = float(input('Please enter number of rooms here: '))
no_of_bed = float(input('Please enter number of bed rooms here: '))
area_pop = float(input('Please enter area population here: '))

user_input = np.array([income, house_age, no_of_rooms, no_of_bed, area_pop])

price = lr.predict(user_input.reshape(1, -1))[0]
print(f'Final Price Prediction: ${price:,.2f}')
# Out:
# Welcome to USA House Price Prediction
# Please enter income here:  90000
# Please enter house age here:  4.35
# Please enter number of rooms here:  3
# Please enter number of bed rooms here:  2
# Please enter area population here:  4458.04
# Final Price Prediction: $466,589.69

# %%
# pick first house
print('Predicted:', y_pred[0])
print('Actual:', y_test.values[0])
print('Difference:', abs(y_pred[0] - y_test.values[0]))
# Out:
# Predicted: 1285338.2399624875
# Actual: 1446155.18
# Difference: 160816.94003751245
